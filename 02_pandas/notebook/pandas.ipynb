# %%
import pandas as pd
import numpy as np

# %%
sales_df = pd.read_csv(
    "../data/sales_data.csv",
    encoding="latin1"
)

# %%
housing_df = pd.read_csv(
    "../data/USA Housing Dataset.csv"
)

# %% [markdown]
# analysis of sales data

# %%
sales_df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
sales_df["SALES"].sum()
# Out:
# np.float64(10032628.85)

# %%
sales_df["SALES"].mean()
# Out:
# np.float64(3553.889071909316)

# %%
sales_df["SALES"].max()
# Out:
# 14082.8

# %%
sales_df.sort_values(
    by="SALES",
    ascending=False
).head(10)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 598         10407               76      100.0                2  14082.8
# 744         10322               50      100.0                6  12536.5
# 53          10424               50      100.0                6  12001.0
# 1062        10412               60      100.0                9  11887.8
# 104         10403               66      100.0                9  11886.6
# 1995        10405               76      100.0                3  11739.7
# 44          10312               48      100.0                3  11623.7
# 1133        10333               46      100.0                2  11336.7
# 188         10127               46      100.0                2  11279.2
# 30          10150               45      100.0                8  10993.5
#
#             ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 598    4/22/2005 0:00     On Hold       2         4     2005  ...
# ...

# %%
sales_df.groupby(
    "PRODUCTLINE"
)["SALES"].sum()
# Out:
# PRODUCTLINE
# Classic Cars        3919615.66
# Motorcycles         1166388.34
# Planes               975003.57
# Ships                714437.13
# Trains               226243.47
# Trucks and Buses    1127789.84
# Vintage Cars        1903150.84
# Name: SALES, dtype: float64

# %%
sales_df.groupby(
    "COUNTRY"
)["SALES"].sum().sort_values(
    ascending=False
)
# Out:
# COUNTRY
# USA            3627982.83
# Spain          1215686.92
# France         1110916.52
# Australia       630623.10
# UK              478880.46
# Italy           374674.31
# Finland         329581.91
# Norway          307463.70
# Singapore       288488.41
# Denmark         245637.15
# Canada          224078.56
# Germany         220472.09
# Sweden          210014.21
# Austria         202062.53
# Japan           188167.81
# Switzerland     117713.56
# Belgium         108412.62
# Philippines      94015.73
# Ireland          57756.43
# Name: SALES, dtype: float64

# %%
sales_df["STATUS"].value_counts()
# Out:
# STATUS
# Shipped       2617
# Cancelled       60
# Resolved        47
# On Hold         44
# In Process      41
# Disputed        14
# Name: count, dtype: int64

# %%
sales_df.groupby(
    "PRODUCTLINE"
)["SALES"].mean()
# Out:
# PRODUCTLINE
# Classic Cars        4053.377104
# Motorcycles         3523.831843
# Planes              3186.286176
# Ships               3053.150128
# Trains              2938.226883
# Trucks and Buses    3746.810100
# Vintage Cars        3135.339110
# Name: SALES, dtype: float64

# %%
sales_df.sort_values(
    by="PRICEEACH",
    ascending=False
).head()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 842         10244               43      100.0                8  5950.34
# 1021        10151               21      100.0                7  3734.01
# 1041        10278               42      100.0                7  6401.22
# 1040        10271               20      100.0                9  3928.60
# 1039        10266               29      100.0                7  4812.55
#
#            ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 842   4/29/2004 0:00  Shipped       2         4     2004  ...
# 1021  9/21/2003 0:00  Shipped       3         9     2003  ...
# 1041   8/6/2004 0:00  Shipped       3         8     2004  ...
# 1040  7/20/2004 0:00  Shipped       3         7     2004  ...
# 1039   7/6/2004 0:00  Shipped       3         7     2004  ...
#
#                 ADDRESSLINE1  ADDRESSLINE2           CITY STATE POSTALCODE  \
# 842       C/ Moralzarzal, 86           NaN         Madrid   NaN      28034
# ...

# %%
sales_df["Revenue_Per_Item"] = (
    sales_df["SALES"] /
    sales_df["QUANTITYORDERED"]
)

sales_df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...          NaN
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...          NaN
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...          NaN
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...          NaN
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...          NaN
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# ...

# %% [markdown]
# analysis using housing dataset

# %%
housing_df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-09 00:00:00   376000.0       3.0       2.00         1340      1384
# 1  2014-05-09 00:00:00   800000.0       4.0       3.25         3540    159430
# 2  2014-05-09 00:00:00  2238888.0       5.0       6.50         7270    130017
# 3  2014-05-09 00:00:00   324000.0       3.0       2.25          998       904
# 4  2014-05-10 00:00:00   549900.0       5.0       2.75         3060      7015
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     3.0           0     0          3        1340              0      2008
# 1     2.0           0     0          3        3540              0      2007
# 2     2.0           0     0          3        6420            850      2010
# 3     2.0           0     0          3         798            200      2007
# 4     1.0           0     0          5        1600           1460      1979
#
# ...

# %%
housing_df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
housing_df["price"].mean()
# Out:
# np.float64(553062.8772890784)

# %%
##high price
housing_df["price"].max()
# Out:
# 26590000.0

# %%
##low price
housing_df["price"].min()
# Out:
# 0.0

# %%
##expensive house
housing_df.sort_values(
    by="price",
    ascending=False
).head(10)
# Out:
#                      date       price  bedrooms  bathrooms  sqft_living  \
# 3890  2014-07-03 00:00:00  26590000.0       3.0       2.00         1180
# 3886  2014-06-23 00:00:00  12899000.0       3.0       2.50         2190
# 1826  2014-06-11 00:00:00   7062500.0       5.0       4.50        10040
# 2194  2014-06-17 00:00:00   4668000.0       5.0       6.75         9640
# 2301  2014-06-18 00:00:00   4489000.0       4.0       3.00         6430
# 3269  2014-07-01 00:00:00   3800000.0       5.0       5.50         7050
# 1177  2014-05-30 00:00:00   3710000.0       4.0       3.50         5550
# 1107  2014-05-29 00:00:00   3100000.0       6.0       4.25         6980
# 2312  2014-06-18 00:00:00   3000000.0       4.0       4.25         4850
# 1868  2014-06-11 00:00:00   2888000.0       5.0       6.25         8670
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 3890      7793     1.0           0     0          4        1180
# ...

# %%
##houses by city
housing_df["city"].value_counts()
# Out:
# city
# Seattle               1415
# Renton                 261
# Bellevue               260
# Redmond                209
# Kent                   167
# Kirkland               166
# Auburn                 162
# Issaquah               162
# Sammamish              158
# Federal Way            131
# Shoreline              112
# Woodinville            103
# Maple Valley            90
# Mercer Island           81
# Snoqualmie              65
# Burien                  64
# Kenmore                 58
# Des Moines              52
# North Bend              45
# Covington               39
# Duvall                  39
# Lake Forest Park        33
# Newcastle               31
# Bothell                 30
# SeaTac                  29
# Vashon                  28
# Tukwila                 28
# Enumclaw                28
# Carnation               18
# Normandy Park           16
# Medina                  11
# Clyde Hill              10
# Fall City                9
# Black Diamond            7
# ...

# %%
##avg price by city
housing_df.groupby(
    "city"
)["price"].mean().sort_values(
    ascending=False
)
# Out:
# city
# Medina                2.046559e+06
# Clyde Hill            1.343140e+06
# Yarrow Point          1.194838e+06
# Mercer Island         1.111306e+06
# Bellevue              8.616365e+05
# Fall City             7.788333e+05
# Beaux Arts Village    7.450000e+05
# Sammamish             6.777309e+05
# Newcastle             6.731424e+05
# Redmond               6.629162e+05
# Kirkland              6.581939e+05
# Woodinville           6.068818e+05
# Issaquah              5.999501e+05
# Seattle               5.776812e+05
# Preston               5.624500e+05
# Ravensdale            5.571250e+05
# Snoqualmie            5.399027e+05
# Carnation             5.300857e+05
# Snoqualmie Pass       5.250000e+05
# Normandy Park         5.044859e+05
# Vashon                4.803268e+05
# Bothell               4.796694e+05
# Kent                  4.538641e+05
# Lake Forest Park      4.417303e+05
# Kenmore               4.407449e+05
# Shoreline             4.196590e+05
# ...

# %% [markdown]
# Feature engineering

# %%
##price per sq feet

housing_df["price_per_sqft"] = (
    housing_df["price"] /
    housing_df["sqft_living"]
)

housing_df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-09 00:00:00   376000.0       3.0       2.00         1340      1384
# 1  2014-05-09 00:00:00   800000.0       4.0       3.25         3540    159430
# 2  2014-05-09 00:00:00  2238888.0       5.0       6.50         7270    130017
# 3  2014-05-09 00:00:00   324000.0       3.0       2.25          998       904
# 4  2014-05-10 00:00:00   549900.0       5.0       2.75         3060      7015
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     3.0           0     0          3        1340              0      2008
# 1     2.0           0     0          3        3540              0      2007
# 2     2.0           0     0          3        6420            850      2010
# 3     2.0           0     0          3         798            200      2007
# 4     1.0           0     0          5        1600           1460      1979
#
# ...

# %%
##correlation
housing_df.corr(
    numeric_only=True
)
# Out:
#                    price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# price           1.000000  0.188765   0.317785     0.418528  0.045964
# bedrooms        0.188765  1.000000   0.542549     0.590110  0.065747
# bathrooms       0.317785  0.542549   1.000000     0.760353  0.097497
# sqft_living     0.418528  0.590110   0.760353     1.000000  0.194226
# sqft_lot        0.045964  0.065747   0.097497     0.194226  1.000000
# floors          0.143180  0.178908   0.487462     0.345130 -0.001113
# waterfront      0.131401 -0.001286   0.080152     0.126157  0.019229
# view            0.217553  0.105512   0.210590     0.308098  0.071264
# condition       0.030327  0.016503  -0.123024    -0.069315  0.012016
# sqft_above      0.355214  0.478124   0.687679     0.874881  0.203190
# sqft_basement   0.204066  0.329862   0.292170     0.439053  0.023567
# yr_built        0.027067  0.153514   0.470814     0.296545  0.047224
# yr_renovated   -0.028272 -0.069439  -0.221307    -0.124646 -0.020308
# ...
